# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# import the csv file and read content
file = pd.read_csv('/kaggle/input/tiktok-google-play-store-review/tiktok_google_play_reviews.csv', low_memory=False) 
# store the file into a DataFrame
df = pd.DataFrame(file)
# calculating the average playstore score
avg_score = df['score'].mean()

# initialize an empty dictionary to store the scores by score key
tt_scores = {}
def score_category(df, col_name):
    """A function to return a iterate through the dataframe to count the recurrences of scores by score"""
    col = df[col_name]
    for score in col:
        # iterates through the score column in the df
        if score in tt_scores:
            # if key is found, it increments by 1
            tt_scores[score] += 1
        else:
            # if it does not find it, it adds a new key and sets the count as 1
            tt_scores[score] = 1
    return tt_scores

results = score_category(df, 'score')

# converting the dictionary into a df to plot
scores = pd.DataFrame(tt_scores.items(), columns=['Score', 'Count'])
print(scores)

# plotting the data
plt.figure(figsize=(10,8))
plt.plot(scores['Count'], scores['Score'])

# Show plot
plt.show()
# Out:
# /kaggle/input/tiktok-google-play-store-review/tiktok_google_play_reviews.csv
#    Score   Count
# 0      5  338894
# 1      1   61928
# 2      4   27665
# 3      3   18620
# 4      2   13180
